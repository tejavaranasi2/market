# %%
from utils import *
from strat import *
test_set=[]

# %%
df=pd.read_csv("output.csv")
plot_3d(df.x,df.y,df.z,"plots/rounding_error.png")

# %%
plt.plot(df.n,df.z,'r^')

# %%
df_t=pd.read_csv("output_ivol_hvol.csv")

df_t=df_t.dropna()
plt.plot(df_t.n,df_t.p1,'r^',label="historic_volaitlity")
plt.plot(df_t.n,df_t.p2,'g^',label="implied_volatility")
plt.legend()
plt.show()

# %%
df_=pd.read_csv("output.csv")

df_=df_.dropna()
df_["ret"]=df_["actual_ret"]/df_["pred_ret"]
df_["ret"]=np.log(df_["ret"])
plt.plot(df_.n,df_.ret,'r^')
print(np.std(df_.ret)**2)
plt.show()
# Out:
# 5.089843363631013e-05
